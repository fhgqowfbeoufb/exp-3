# %% [markdown]
# <a href="https://colab.research.google.com/github/fhgqowfbeoufb/exp-3/blob/main/exp0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Explanatory Data Analysis
# ##Basics of Python
# ###Expt-0

# %%
# Yogesh Shendage / 25070123128

print("Yogesh Shendage")
# Out:
# Yogesh Shendage

# %%
print(2)
# Out:
# 2

# %%
ar=[1,2,5]
print(ar)
# Out:
# [1, 2, 5]

# %%
print("Yogesh Shendage\n",2,"\n",ar)
# Out:
# Yogesh Shendage
#  2
#  [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="Yogesh Shendage"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Yogesh Shendage
